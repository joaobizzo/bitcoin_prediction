# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pycaret.regression import *
import datetime

# %%
SEED = 61

# %%
assets = pd.read_csv('archive/BTC-2021min.csv')
assets.head()
# Out:
#          unix                 date   symbol      open      high       low  \
# 0  1646106180  2022-03-01 03:43:00  BTC/USD  43046.58  43046.58  43046.58
# 1  1646106060  2022-03-01 03:41:00  BTC/USD  43018.23  43046.59  43018.23
# 2  1646106000  2022-03-01 03:40:00  BTC/USD  43022.24  43022.24  43016.03
# 3  1646105940  2022-03-01 03:39:00  BTC/USD  43035.16  43035.16  42999.44
# 4  1646105880  2022-03-01 03:38:00  BTC/USD  43077.82  43077.82  43049.46
#
#       close  Volume BTC    Volume USD
# 0  43046.58    0.000000      0.000000
# 1  43046.58    0.142977   6154.673021
# 2  43016.03    0.009230    397.037957
# 3  42999.44    0.820950  35300.390268
# 4  43049.46    0.022210    956.143143

# %%
future_days = 1 * (60 * 24)
# Create a new column (the target or dependent variable) which is shifted 'n' units up
assets['Future_Price'] = assets[['close']].shift(-future_days)

#Choosing the features
assets = assets[['close', 'Future_Price']]
#Show the assets data set
assets.head()
# Out:
#       close  Future_Price
# 0  43046.58      37889.43
# 1  43046.58      37837.18
# 2  43016.03      37817.73
# 3  42999.44      37851.62
# 4  43049.46      37817.04

# %%
#Copy the assets data set to a new data set
df = assets.copy()

#Create the independet data set (X)
X = np.array(df[df.columns])
#Remove the last 'n' rows
X = X[:len(assets)-future_days]

#Create the dependent data set (y)
y = np.array(df['Future_Price'])
#Get all of the y values except the last 'n' rows
y = y[:-future_days]

#Split the data into 85% training and 15% testing
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=SEED)

# %%
#Transform the train array in a dataframe
train_data = pd.DataFrame(x_train, columns=df.columns)

train_data.head(7)
# Out:
#       close  Future_Price
# 0  46985.40      46922.01
# 1  56598.21      56439.38
# 2  59537.61      59523.54
# 3  31665.06      31661.87
# 4  39400.84      39344.62
# 5  43938.78      44099.78
# 6  58140.76      58067.97

# %%
#Transform the test array in a dataframe
test_data = pd.DataFrame(x_test, columns=df.columns)

test_data.head(7)
# Out:
#       close  Future_Price
# 0  63807.43      63820.18
# 1  61421.68      61400.14
# 2  35223.93      35225.00
# 3  57167.51      57212.22
# 4  38038.14      38073.67
# 5  34494.08      34497.30
# 6  47536.99      47483.98

# %%
#Initialize the setup
regression_setup = setup(data=train_data, target='Future_Price', session_id=123, use_gpu=True)
# Out:
# <style type="text/css">
# #T_b1440_row8_col1, #T_b1440_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1440">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1440_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b1440_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1440_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1440_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b1440_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1440_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b1440_row1_col1" class="data row1 col1" >Future_Price</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1440_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b1440_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1440_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b1440_row3_col1" class="data row3 col1" >(519162, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1440_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b1440_row4_col1" class="data row4 col1" >(519162, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1440_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b1440_row5_col1" class="data row5 col1" >(363413, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1440_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b1440_row6_col1" class="data row6 col1" >(155749, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1440_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b1440_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1440_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b1440_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1440_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b1440_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1440_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b1440_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b1440_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b1440_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b1440_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b1440_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b1440_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b1440_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b1440_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b1440_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b1440_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b1440_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b1440_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b1440_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b1440_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b1440_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b1440_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b1440_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b1440_row18_col1" class="data row18 col1" >1eac</td>
#     </tr>
#   </tbody>
# </table>

# %%
# best_model = compare_models(sort='r2')
#best model for this database is linear regression
best_model = 'lr'

# %%
# create model
model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_8671a_row10_col0, #T_8671a_row10_col1, #T_8671a_row10_col2, #T_8671a_row10_col3, #T_8671a_row10_col4, #T_8671a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8671a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8671a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8671a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8671a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8671a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8671a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8671a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8671a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8671a_row0_col0" class="data row0 col0" >62.9827</td>
#       <td id="T_8671a_row0_col1" class="data row0 col1" >9462.1289</td>
#       <td id="T_8671a_row0_col2" class="data row0 col2" >97.2735</td>
#       <td id="T_8671a_row0_col3" class="data row0 col3" >0.9999</td>
#       <td id="T_8671a_row0_col4" class="data row0 col4" >0.0022</td>
#       <td id="T_8671a_row0_col5" class="data row0 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8671a_row1_col0" class="data row1 col0" >63.7178</td>
#       <td id="T_8671a_row1_col1" class="data row1 col1" >9752.6533</td>
#       <td id="T_8671a_row1_col2" class="data row1 col2" >98.7555</td>
#       <td id="T_8671a_row1_col3" class="data row1 col3" >0.9999</td>
#       <td id="T_8671a_row1_col4" class="data row1 col4" >0.0023</td>
#       <td id="T_8671a_row1_col5" class="data row1 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8671a_row2_col0" class="data row2 col0" >63.4753</td>
#       <td id="T_8671a_row2_col1" class="data row2 col1" >9623.6416</td>
#       <td id="T_8671a_row2_col2" class="data row2 col2" >98.1002</td>
#       <td id="T_8671a_row2_col3" class="data row2 col3" >0.9999</td>
#       <td id="T_8671a_row2_col4" class="data row2 col4" >0.0022</td>
#       <td id="T_8671a_row2_col5" class="data row2 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8671a_row3_col0" class="data row3 col0" >63.0465</td>
#       <td id="T_8671a_row3_col1" class="data row3 col1" >9112.1875</td>
#       <td id="T_8671a_row3_col2" class="data row3 col2" >95.4578</td>
#       <td id="T_8671a_row3_col3" class="data row3 col3" >0.9999</td>
#       <td id="T_8671a_row3_col4" class="data row3 col4" >0.0022</td>
#       <td id="T_8671a_row3_col5" class="data row3 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8671a_row4_col0" class="data row4 col0" >63.3850</td>
#       <td id="T_8671a_row4_col1" class="data row4 col1" >9688.7471</td>
#       <td id="T_8671a_row4_col2" class="data row4 col2" >98.4314</td>
#       <td id="T_8671a_row4_col3" class="data row4 col3" >0.9999</td>
#       <td id="T_8671a_row4_col4" class="data row4 col4" >0.0022</td>
#       <td id="T_8671a_row4_col5" class="data row4 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8671a_row5_col0" class="data row5 col0" >63.5868</td>
#       <td id="T_8671a_row5_col1" class="data row5 col1" >10663.1143</td>
#       <td id="T_8671a_row5_col2" class="data row5 col2" >103.2624</td>
#       <td id="T_8671a_row5_col3" class="data row5 col3" >0.9999</td>
#       <td id="T_8671a_row5_col4" class="data row5 col4" >0.0023</td>
#       <td id="T_8671a_row5_col5" class="data row5 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8671a_row6_col0" class="data row6 col0" >63.4214</td>
#       <td id="T_8671a_row6_col1" class="data row6 col1" >9714.7959</td>
#       <td id="T_8671a_row6_col2" class="data row6 col2" >98.5637</td>
#       <td id="T_8671a_row6_col3" class="data row6 col3" >0.9999</td>
#       <td id="T_8671a_row6_col4" class="data row6 col4" >0.0022</td>
#       <td id="T_8671a_row6_col5" class="data row6 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8671a_row7_col0" class="data row7 col0" >62.9169</td>
#       <td id="T_8671a_row7_col1" class="data row7 col1" >9275.5518</td>
#       <td id="T_8671a_row7_col2" class="data row7 col2" >96.3097</td>
#       <td id="T_8671a_row7_col3" class="data row7 col3" >0.9999</td>
#       <td id="T_8671a_row7_col4" class="data row7 col4" >0.0022</td>
#       <td id="T_8671a_row7_col5" class="data row7 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8671a_row8_col0" class="data row8 col0" >62.9042</td>
#       <td id="T_8671a_row8_col1" class="data row8 col1" >9582.3818</td>
#       <td id="T_8671a_row8_col2" class="data row8 col2" >97.8896</td>
#       <td id="T_8671a_row8_col3" class="data row8 col3" >0.9999</td>
#       <td id="T_8671a_row8_col4" class="data row8 col4" >0.0023</td>
#       <td id="T_8671a_row8_col5" class="data row8 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8671a_row9_col0" class="data row9 col0" >63.5787</td>
#       <td id="T_8671a_row9_col1" class="data row9 col1" >9852.8408</td>
#       <td id="T_8671a_row9_col2" class="data row9 col2" >99.2615</td>
#       <td id="T_8671a_row9_col3" class="data row9 col3" >0.9999</td>
#       <td id="T_8671a_row9_col4" class="data row9 col4" >0.0023</td>
#       <td id="T_8671a_row9_col5" class="data row9 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8671a_row10_col0" class="data row10 col0" >63.3015</td>
#       <td id="T_8671a_row10_col1" class="data row10 col1" >9672.8043</td>
#       <td id="T_8671a_row10_col2" class="data row10 col2" >98.3305</td>
#       <td id="T_8671a_row10_col3" class="data row10 col3" >0.9999</td>
#       <td id="T_8671a_row10_col4" class="data row10 col4" >0.0023</td>
#       <td id="T_8671a_row10_col5" class="data row10 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_8671a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8671a_row11_col0" class="data row11 col0" >0.2925</td>
#       <td id="T_8671a_row11_col1" class="data row11 col1" >393.5223</td>
#       <td id="T_8671a_row11_col2" class="data row11 col2" >1.9783</td>
#       <td id="T_8671a_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_8671a_row11_col4" class="data row11 col4" >0.0000</td>
#       <td id="T_8671a_row11_col5" class="data row11 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#evaluate model
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#predict model
useen_predictions = predict_model(model, data=test_data)

useen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0f9a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f9a3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0f9a3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0f9a3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0f9a3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0f9a3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0f9a3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0f9a3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f9a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f9a3_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_0f9a3_row0_col1" class="data row0 col1" >63.1961</td>
#       <td id="T_0f9a3_row0_col2" class="data row0 col2" >9384.9863</td>
#       <td id="T_0f9a3_row0_col3" class="data row0 col3" >96.8761</td>
#       <td id="T_0f9a3_row0_col4" class="data row0 col4" >0.9999</td>
#       <td id="T_0f9a3_row0_col5" class="data row0 col5" >0.0022</td>
#       <td id="T_0f9a3_row0_col6" class="data row0 col6" >0.0014</td>
#     </tr>
#   </tbody>
# </table>
#           close  Future_Price  prediction_label
# 0  63807.429688  63820.179688      63806.425781
# 1  61421.679688  61400.140625      61420.816406
# 2  35223.929688  35225.000000      35224.574219
# 3  57167.511719  57212.218750      57166.890625
# 4  38038.140625  38073.671875      38038.621094
